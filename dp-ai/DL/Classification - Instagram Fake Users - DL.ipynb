# %%
import pandas as pd
from jinja2 import optimizer

df = pd.read_csv("user_fake_authentic_2class.csv")

# 'class' 열의 문자열 값을 숫자로 변환 (예: 'f' -> 0, 'r' -> 1)
df['class'] = df['class'].apply(lambda x: 0 if x == 'f' else 1)

display(df.head())
#사이킬런 파이썬 라이브러리
#머신러닝 관련 lib. 여기에 kford: t, v , t 데이터 나눠주는게 있음
#판다스로 로드에서 받은거 알려줌.
#레이블 비율 똑같이
# Out:
#    pos  flw  flg   bl  pic  lin   cl   cz   ni    erl   erc     lt   hc   pr  \
# 0   44   48  325   33    1    0   12  0.0  0.0   0.00  0.00  0.000  0.0  0.0
# 1   10   66  321  150    1    0  213  0.0  1.0  14.39  1.97  0.000  1.5  0.0
# 2   33  970  308  101    1    1  436  0.0  1.0  10.10  0.30  0.000  2.5  0.0
# 3   70   86  360   14    1    0    0  1.0  0.0   0.78  0.06  0.000  0.0  0.0
# 4    3   21  285   73    1    0   93  0.0  0.0  14.29  0.00  0.667  0.0  0.0
#
#       fo        cs          pi  class
# 0  0.000  0.111111    0.094985      0
# 1  0.000  0.206826  230.412857      0
# 2  0.056  0.572174   43.569939      0
# 3  0.000  1.000000    5.859799      0
# 4  0.000  0.300494    0.126019      0

# %%
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, TensorDataset

train_valid, test = train_test_split(df, test_size=0.2,stratify=df['class'] ,random_state=42)

train, valid = train_test_split(train_valid, test_size=0.25, stratify=train_valid['class'], random_state=42)

# 각 데이터 세트의 class 비율 확인
print("Train class distribution:")
print(train['class'].value_counts(normalize=True))

print("\nValidation class distribution:")
print(valid['class'].value_counts(normalize=True))

print("\nTest class distribution:")
print(test['class'].value_counts(normalize=True))

# Y is target variable.

# Train data
X_train, y_train = train.drop(columns=['class']).values, train['class'].values
# Valid data
X_valid, y_valid = valid.drop(columns=['class']).values, valid['class'].values
# Test data
X_test, y_test = test.drop(columns=['class']).values, test['class'].values

# Numpy 배열을 PyTorch 텐서로 변환 for DL input
X_train, y_train = torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.long)
X_valid, y_valid = torch.tensor(X_valid, dtype=torch.float32), torch.tensor(y_valid, dtype=torch.long)
X_test, y_test = torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.long)

# DataLoader 생성
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# Train class distribution:
# class
# 0    0.5031
# 1    0.4969
# Name: proportion, dtype: float64
#
# Validation class distribution:
# class
# 0    0.5031
# 1    0.4969
# Name: proportion, dtype: float64
#
# Test class distribution:
# class
# 0    0.503138
# 1    0.496862
# Name: proportion, dtype: float64

# %%
import torch.nn as nn

class SimpleMLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(SimpleMLP, self).__init__()
        # 6개의 hidden layer
        self.fc1 = nn.Linear(17, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 32)
        self.fc6 = nn.Linear(32, 2)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out
    
# 파라미터 설정
input_size = X_train.shape[1] #17
hidden_size = input_size-1 #TODO : 적절한 히든레이어 사이즈 경험적으로 만들기
num_classes = len(set(y_train.numpy())) # 2

print(input_size, hidden_size, num_classes)
learning_rate = 0.001

# 모델 초기화
model = SimpleMLP(input_size, hidden_size,num_classes) #
# Out:
# 17 16 2

# %%
# 손실 함수와 옵티마이저 정의
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# 학습 설정
num_epochs = 50

# 모델 학습
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        # 순전파
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # 역전파 및 옵티마이저 단계
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    
    # 검증 세트에서 모델 평가
    model.eval()
    valid_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in valid_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {running_loss/len(train_loader):.4f}, '
          f'Validation Loss: {valid_loss/len(valid_loader):.4f}, '
          f'Validation Accuracy: {correct/total:.4f}')
# Out:
# Epoch [1/50], Train Loss: 17.3765, Validation Loss: 12.2054, Validation Accuracy: 0.7333
# Epoch [2/50], Train Loss: 9.3043, Validation Loss: 4.5438, Validation Accuracy: 0.7182
# Epoch [3/50], Train Loss: 5.9771, Validation Loss: 37.4673, Validation Accuracy: 0.7344
# Epoch [4/50], Train Loss: 4.4371, Validation Loss: 10.1619, Validation Accuracy: 0.7137
# Epoch [5/50], Train Loss: 3.1239, Validation Loss: 2.6578, Validation Accuracy: 0.7519
# Epoch [6/50], Train Loss: 3.4296, Validation Loss: 3.0858, Validation Accuracy: 0.7174
# Epoch [7/50], Train Loss: 2.3896, Validation Loss: 6.0739, Validation Accuracy: 0.7865
# Epoch [8/50], Train Loss: 1.5071, Validation Loss: 1.7445, Validation Accuracy: 0.7594
# Epoch [9/50], Train Loss: 1.0595, Validation Loss: 1.5803, Validation Accuracy: 0.6844
# Epoch [10/50], Train Loss: 0.8744, Validation Loss: 0.8766, Validation Accuracy: 0.7975
# Epoch [11/50], Train Loss: 0.8473, Validation Loss: 1.2237, Validation Accuracy: 0.7966
# Epoch [12/50], Train Loss: 0.5416, Validation Loss: 0.5331, Validation Accuracy: 0.8174
# Epoch [13/50], Train Loss: 0.6031, Validation Loss: 1.5007, Validation Accuracy: 0.7917
# Epoch [14/50], Train Loss: 0.5109, Validation Loss: 0.6852, Validation Accuracy: 0.8194
# Epoch [15/50], Train Loss: 0.4307, Validation Loss: 0.4846, Validation Accuracy: 0.8405
# Epoch [16/50], Train Loss: 0.4339, Validation Loss: 0.4441, Validation Accuracy: 0.8090
# Epoch [17/50], Train Loss: 0.4348, Validation Loss: 0.8551, Validation Accuracy: 0.8284
# Epoch [18/50], Train Loss: 0.4421, Validation Loss: 0.6116, Validation Accuracy: 0.7871
# Epoch [19/50], Train Loss: 0.4436, Validation Loss: 0.7872, Validation Accuracy: 0.8302
# Epoch [20/50], Train Loss: 0.5091, Validation Loss: 0.6879, Validation Accuracy: 0.8419
# Epoch [21/50], Train Loss: 0.4193, Validation Loss: 0.4283, Validation Accuracy: 0.8439
# Epoch [22/50], Train Loss: 0.4097, Validation Loss: 0.4476, Validation Accuracy: 0.8471
# Epoch [23/50], Train Loss: 0.4745, Validation Loss: 0.7279, Validation Accuracy: 0.8442
# Epoch [24/50], Train Loss: 0.4176, Validation Loss: 0.5559, Validation Accuracy: 0.8474
# Epoch [25/50], Train Loss: 0.3932, Validation Loss: 0.4116, Validation Accuracy: 0.8449
# Epoch [26/50], Train Loss: 0.4028, Validation Loss: 1.0334, Validation Accuracy: 0.8452
# Epoch [27/50], Train Loss: 0.4088, Validation Loss: 0.4571, Validation Accuracy: 0.8351
# Epoch [28/50], Train Loss: 0.3733, Validation Loss: 0.4033, Validation Accuracy: 0.8459
# Epoch [29/50], Train Loss: 0.4048, Validation Loss: 0.6392, Validation Accuracy: 0.8550
# Epoch [30/50], Train Loss: 0.3863, Validation Loss: 0.4203, Validation Accuracy: 0.8593
# Epoch [31/50], Train Loss: 0.4142, Validation Loss: 0.5801, Validation Accuracy: 0.8463
# Epoch [32/50], Train Loss: 0.4199, Validation Loss: 0.7360, Validation Accuracy: 0.8251
# Epoch [33/50], Train Loss: 0.4070, Validation Loss: 0.5749, Validation Accuracy: 0.8374
# Epoch [34/50], Train Loss: 0.3690, Validation Loss: 0.3857, Validation Accuracy: 0.8582
# Epoch [35/50], Train Loss: 0.3777, Validation Loss: 0.4139, Validation Accuracy: 0.8491
# Epoch [36/50], Train Loss: 0.3701, Validation Loss: 0.4488, Validation Accuracy: 0.8197
# Epoch [37/50], Train Loss: 0.3713, Validation Loss: 0.4129, Validation Accuracy: 0.8425
# Epoch [38/50], Train Loss: 0.3649, Validation Loss: 0.3796, Validation Accuracy: 0.8527
# Epoch [39/50], Train Loss: 0.3625, Validation Loss: 0.4625, Validation Accuracy: 0.8197
# Epoch [40/50], Train Loss: 0.3961, Validation Loss: 0.5384, Validation Accuracy: 0.8582
# Epoch [41/50], Train Loss: 0.4002, Validation Loss: 0.4132, Validation Accuracy: 0.8463
# Epoch [42/50], Train Loss: 0.3533, Validation Loss: 0.3436, Validation Accuracy: 0.8583
# Epoch [43/50], Train Loss: 0.3725, Validation Loss: 0.4027, Validation Accuracy: 0.8488
# Epoch [44/50], Train Loss: 0.3588, Validation Loss: 0.3691, Validation Accuracy: 0.8413
# Epoch [45/50], Train Loss: 0.3570, Validation Loss: 0.7381, Validation Accuracy: 0.8509
# Epoch [46/50], Train Loss: 0.3650, Validation Loss: 0.3987, Validation Accuracy: 0.8605
# Epoch [47/50], Train Loss: 0.3629, Validation Loss: 0.3357, Validation Accuracy: 0.8581
# Epoch [48/50], Train Loss: 0.3336, Validation Loss: 0.3404, Validation Accuracy: 0.8600
# Epoch [49/50], Train Loss: 0.3346, Validation Loss: 0.3391, Validation Accuracy: 0.8539
# Epoch [50/50], Train Loss: 0.4238, Validation Loss: 0.4913, Validation Accuracy: 0.8376

# %%
# 모델 평가
model.eval()
test_loss = 0.0
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Test Loss: {test_loss/len(test_loader):.4f}')
print(f'Test Accuracy: {correct/total:.4f}')
# Out:
# Test Loss: 0.4811
# Test Accuracy: 0.8347
